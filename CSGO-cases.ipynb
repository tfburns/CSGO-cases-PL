# %% [markdown]
# ## CS:GO Skin Win probabilities
#
# YouTuber [3kliksphilip](https://www.youtube.com/channel/UCmu9PVIZBk-ZCi-Sk2F2utA) recently posted a video titled ["Case Unboxing Millionaire #2"](https://www.youtube.com/watch?v=a-FdnfZhguw), wherein he showed a single run simulation of him 'unboxing' cases for the first-person-shooter computer game Counter Strike: Global Offensive. These cases are digital items which, when opened, unlock a decorative weapon 'skin'. These skins can be used by players in the game to show off to their friends. Such skins have deveoped quite a market for themselves and can be bought and sold for hundreds or even thousands of dollars through various online marketplaces.
#
# The following analysis calculates the expected profit or loss for a given case, "eSports 2013 Case", per opening. It costs \\$20 to open, and can contain skins worth between a few dollars to around \\$300. 3kliksphilip challenged his viewers to estimate his profit or loss from opening this case up until he unlocked a knife skin, the rarest skin to obatin. I have calculated this expected value to be a loss of \\$5720.96.

# %%
import json
import random
import numpy as np

# %%
# 'prices_v4.json' downloaded (from https://csgotrader.app/prices/)
with open('prices_v4.json') as f:
  data = json.load(f)

# %%
data
# Out:
# {'★ M9 Bayonet | Damascus Steel (Factory New)': {'steam': {'last_90d': 258.27,
#    'last_30d': 261.62,
#    'last_7d': 263.46,
#    'last_24h': 306},
#   'bitskins': {'price': '174.5', 'instant_sale_price': '69.8'},
#   'lootfarm': 312.08,
#   'csgotm': '415.631',
#   'csmoney': {'price': 296.85},
#   'skincay': {'suggested_price': 178,
#    'steam_price': 228.21,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 265.61}},
#  'StatTrak™ MAC-10 | Stalker (Factory New)': {'steam': {'last_90d': 235.17,
#    'last_30d': 247.73,
#    'last_7d': 202.54,
#    'last_24h': 0},
#   'bitskins': {'price': '257.56', 'instant_sale_price': '103.02'},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 280.21},
#   'skincay': {'suggested_price': 177.26,
#    'steam_price': 227.26,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 257.47}},
#  'AWP | Fever Dream (Minimal Wear)': {'steam': {'last_90d': 6.93,
#    'last_30d': 6.66,
#    'last_7d': 6.69,
#    'last_24h': 6.7},
#   'bitskins': {'price': '6.99', 'instant_sale_price': '2.8'},
#   'lootfarm': 6.85,
#   'csgotm': '5.389',
#   'csmoney': {'price': 6.17},
#   'skincay': {'suggested_price': 4.77,
#    'steam_price': 6.12,
#    'instant_price': None,
#    'starting_at': 4.76},
#   'csgotrader': {'price': 6.7}},
#  'G3SG1 | Arctic Camo (Field-Tested)': {'steam': {'last_90d': 1.75,
#    'last_30d': 1.75,
#    'last_7d': 1.86,
#    'last_24h': 0},
#   'bitskins': {'price': '0.92', 'instant_sale_price': None},
#   'lootfarm': 1.65,
#   'csgotm': '2.356',
#   'csmoney': {'price': 2.07},
#   'skincay': {'suggested_price': 1.26,
#    'steam_price': 1.61,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.88}},
#  'AK-47 | Rat Rod (Factory New)': {'steam': {'last_90d': 9.26,
#    'last_30d': 9.92,
#    'last_7d': 10.42,
#    'last_24h': 10.55},
#   'bitskins': {'price': '9.86', 'instant_sale_price': '3.94'},
#   'lootfarm': 10.34,
#   'csgotm': '11.174',
#   'csmoney': {'price': 11.16},
#   'skincay': {'suggested_price': 7.07,
#    'steam_price': 9.07,
#    'instant_price': None,
#    'starting_at': 7.5},
#   'csgotrader': {'price': 10.55}},
#  'Music Kit | Daniel Sadowski, Crimson Assault': {'steam': {'last_90d': 2.89,
#    'last_30d': 2.92,
#    'last_7d': 2.88,
#    'last_24h': 2.93},
#   'bitskins': {'price': '4.94', 'instant_sale_price': '1.48'},
#   'lootfarm': 2.84,
#   'csgotm': '3.001',
#   'csmoney': {'price': 2.84},
#   'skincay': {'suggested_price': 2.1,
#    'steam_price': 2.69,
#    'instant_price': None,
#    'starting_at': 2.12},
#   'csgotrader': {'price': 2.93}},
#  'SG 553 | Colony IV (Well-Worn)': {'steam': {'last_90d': 2.4,
#    'last_30d': 2.39,
#    'last_7d': 2.62,
#    'last_24h': 2.55},
#   'bitskins': {'price': '2.3', 'instant_sale_price': None},
#   'lootfarm': 2.63,
#   'csgotm': '2.589',
#   'csmoney': {'price': 2.71},
#   'skincay': {'suggested_price': 1.72,
#    'steam_price': 2.2,
#    'instant_price': None,
#    'starting_at': 1.82},
#   'csgotrader': {'price': 2.55}},
#  '★ Talon Knife | Blue Steel (Field-Tested)': {'steam': {'last_90d': 256.06,
#    'last_30d': 262.53,
#    'last_7d': 267.48,
#    'last_24h': 287},
#   'bitskins': {'price': '293.56', 'instant_sale_price': '117.42'},
#   'lootfarm': 299.95,
#   'csgotm': '240.174',
#   'csmoney': {'price': 279.78},
#   'skincay': {'suggested_price': 187.13,
#    'steam_price': 239.91,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 269.67}},
#  'XM1014 | VariCamo Blue (Factory New)': {'steam': {'last_90d': 4.9,
#    'last_30d': 4.85,
#    'last_7d': 4.73,
#    'last_24h': 4.44},
#   'bitskins': {'price': '4.4', 'instant_sale_price': '1.76'},
#   'lootfarm': 4.49,
#   'csgotm': 'null',
#   'csmoney': {'price': 5.19},
#   'skincay': {'suggested_price': 3.48,
#    'steam_price': 4.46,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 4.77}},
#  'Sealed Graffiti | Oops (Blood Red)': {'steam': {'last_90d': 0.09,
#    'last_30d': 0.14,
#    'last_7d': 0.17,
#    'last_24h': 0.17},
#   'bitskins': {'price': '0.09', 'instant_sale_price': None},
#   'lootfarm': 0.13,
#   'csgotm': '0.685',
#   'csmoney': {'price': 0.14},
#   'skincay': {'suggested_price': 0.1,
#    'steam_price': 0.13,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.17}},
#  'XM1014 | Scumbria (Well-Worn)': {'steam': {'last_90d': 0.09,
#    'last_30d': 0.09,
#    'last_7d': 0.1,
#    'last_24h': 0.09},
#   'bitskins': {'price': '0.11', 'instant_sale_price': None},
#   'lootfarm': 0.09,
#   'csgotm': '0.095',
#   'csmoney': {'price': 0.08},
#   'skincay': {'suggested_price': 0.06,
#    'steam_price': 0.08,
#    'instant_price': None,
#    'starting_at': 0.1},
#   'csgotrader': {'price': 0.1}},
#  'AK-47 | Hydroponic (Field-Tested)': {'steam': {'last_90d': 167.3,
#    'last_30d': 180.7,
#    'last_7d': 195.19,
#    'last_24h': 218.71},
#   'bitskins': {'price': '148.06', 'instant_sale_price': '59.22'},
#   'lootfarm': 202.87,
#   'csgotm': '197.718',
#   'csmoney': {'price': 221.42},
#   'skincay': {'suggested_price': 127.8,
#    'steam_price': 163.85,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 196.79}},
#  'Sticker | Pocket BBQ': {'steam': {'last_90d': 0.36,
#    'last_30d': 0.36,
#    'last_7d': 0.37,
#    'last_24h': 0.38},
#   'bitskins': {'price': '0.42', 'instant_sale_price': None},
#   'lootfarm': 0.33,
#   'csgotm': '0.541',
#   'csmoney': {'price': 0.37},
#   'skincay': {'suggested_price': 0.26,
#    'steam_price': 0.33,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.38}},
#  'AUG | Arctic Wolf (Minimal Wear)': {'steam': {'last_90d': 2.05,
#    'last_30d': 2,
#    'last_7d': 2.05,
#    'last_24h': 2.08},
#   'bitskins': {'price': '1.99', 'instant_sale_price': None},
#   'lootfarm': 2.03,
#   'csgotm': '1.827',
#   'csmoney': {'price': 1.85},
#   'skincay': {'suggested_price': 1.43,
#    'steam_price': 1.83,
#    'instant_price': None,
#    'starting_at': 1.43},
#   'csgotrader': {'price': 2.08}},
#  'StatTrak™ SG 553 | Cyrex (Well-Worn)': {'steam': {'last_90d': 10.5,
#    'last_30d': 9.59,
#    'last_7d': 8.82,
#    'last_24h': 8.78},
#   'bitskins': {'price': '19.35', 'instant_sale_price': '7.74'},
#   'lootfarm': 8.78,
#   'csgotm': '10.068',
#   'csmoney': {'price': 9.71},
#   'skincay': {'suggested_price': 7.18,
#    'steam_price': 9.21,
#    'instant_price': None,
#    'starting_at': 6.96},
#   'csgotrader': {'price': 8.78}},
#  'MP9 | Dart (Well-Worn)': {'steam': {'last_90d': 0.33,
#    'last_30d': 0.33,
#    'last_7d': 0.34,
#    'last_24h': 0.38},
#   'bitskins': {'price': '0.37', 'instant_sale_price': None},
#   'lootfarm': 0.32,
#   'csgotm': '0.838',
#   'csmoney': {'price': 0.37},
#   'skincay': {'suggested_price': 0.24,
#    'steam_price': 0.31,
#    'instant_price': None,
#    'starting_at': 0.23},
#   'csgotrader': {'price': 0.34}},
#  'StatTrak™ SSG 08 | Bloodshot (Field-Tested)': {'steam': {'last_90d': 8.96,
#    'last_30d': 9.46,
#    'last_7d': 9.85,
#    'last_24h': 9.64},
#   'bitskins': {'price': '9.52', 'instant_sale_price': '3.81'},
#   'lootfarm': 9.93,
#   'csgotm': '9.845',
#   'csmoney': {'price': 11.15},
#   'skincay': {'suggested_price': 6.75,
#    'steam_price': 8.66,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 9.64}},
#  'Tec-9 | Decimator (Minimal Wear)': {'steam': {'last_90d': 7.66,
#    'last_30d': 8.37,
#    'last_7d': 9.28,
#    'last_24h': 9.5},
#   'bitskins': {'price': '8.37', 'instant_sale_price': '3.35'},
#   'lootfarm': 9.17,
#   'csgotm': '9.061',
#   'csmoney': {'price': 10.53},
#   'skincay': {'suggested_price': 5.94,
#    'steam_price': 7.61,
#    'instant_price': None,
#    'starting_at': 6.36},
#   'csgotrader': {'price': 9.5}},
#  'StatTrak™ SSG 08 | Necropos (Battle-Scarred)': {'steam': {'last_90d': 1.12,
#    'last_30d': 1.08,
#    'last_7d': 1.05,
#    'last_24h': 1.03},
#   'bitskins': {'price': '1.27', 'instant_sale_price': None},
#   'lootfarm': 1.01,
#   'csgotm': '0.938',
#   'csmoney': {'price': 1.11},
#   'skincay': {'suggested_price': 0.77,
#    'steam_price': 0.99,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.03}},
#  'StatTrak™ MAC-10 | Lapis Gator (Minimal Wear)': {'steam': {'last_90d': 0.95,
#    'last_30d': 0.95,
#    'last_7d': 0.92,
#    'last_24h': 0.95},
#   'bitskins': {'price': '0.96', 'instant_sale_price': None},
#   'lootfarm': 0.88,
#   'csgotm': '1.236',
#   'csmoney': {'price': 1.01},
#   'skincay': {'suggested_price': 0.68,
#    'steam_price': 0.87,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.95}},
#  'M4A1-S | Moss Quartz (Field-Tested)': {'steam': {'last_90d': 1.15,
#    'last_30d': 1.4,
#    'last_7d': 1.91,
#    'last_24h': 1.92},
#   'bitskins': {'price': '1.39', 'instant_sale_price': None},
#   'lootfarm': 1.71,
#   'csgotm': '1.687',
#   'csmoney': {'price': 1.75},
#   'skincay': {'suggested_price': 0.99,
#    'steam_price': 1.27,
#    'instant_price': None,
#    'starting_at': 2},
#   'csgotrader': {'price': 1.92}},
#  'Sealed Graffiti | Virtus.Pro | Krakow 2017': {'steam': {'last_90d': 0.82,
#    'last_30d': 0.85,
#    'last_7d': 0.89,
#    'last_24h': 0.83},
#   'bitskins': {'price': '0.91', 'instant_sale_price': None},
#   'lootfarm': 0.82,
#   'csgotm': 'null',
#   'csmoney': {'price': 0.9},
#   'skincay': {'suggested_price': 0.61,
#    'steam_price': 0.78,
#    'instant_price': None,
#    'starting_at': 0.66},
#   'csgotrader': {'price': 0.83}},
#  'M4A1-S | Flashback (Field-Tested)': {'steam': {'last_90d': 0.86,
#    'last_30d': 0.96,
#    'last_7d': 0.93,
#    'last_24h': 0.91},
#   'bitskins': {'price': '0.83', 'instant_sale_price': None},
#   'lootfarm': 0.89,
#   'csgotm': '0.825',
#   'csmoney': {'price': 0.81},
#   'skincay': {'suggested_price': 0.69,
#    'steam_price': 0.88,
#    'instant_price': None,
#    'starting_at': 0.7},
#   'csgotrader': {'price': 0.91}},
#  'M4A1-S | Hyper Beast (Factory New)': {'steam': {'last_90d': 67.31,
#    'last_30d': 74.19,
#    'last_7d': 77.44,
#    'last_24h': 79.23},
#   'bitskins': {'price': '56.53', 'instant_sale_price': '22.61'},
#   'lootfarm': 84.09,
#   'csgotm': '71.909',
#   'csmoney': {'price': 87.98},
#   'skincay': {'suggested_price': 53.06,
#    'steam_price': 68.02,
#    'instant_price': None,
#    'starting_at': 99.99},
#   'csgotrader': {'price': 79.23}},
#  'Tec-9 | Avalanche (Well-Worn)': {'steam': {'last_90d': 0.98,
#    'last_30d': 1.01,
#    'last_7d': 1.03,
#    'last_24h': 1.06},
#   'bitskins': {'price': '1.06', 'instant_sale_price': None},
#   'lootfarm': 0.97,
#   'csgotm': '1.365',
#   'csmoney': {'price': 1.09},
#   'skincay': {'suggested_price': 0.73,
#    'steam_price': 0.93,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.06}},
#  'XM1014 | Teclu Burner (Field-Tested)': {'steam': {'last_90d': 1.08,
#    'last_30d': 1.16,
#    'last_7d': 1.19,
#    'last_24h': 1.18},
#   'bitskins': {'price': '1.26', 'instant_sale_price': None},
#   'lootfarm': 1.1,
#   'csgotm': '1.066',
#   'csmoney': {'price': 1.19},
#   'skincay': {'suggested_price': 0.83,
#    'steam_price': 1.06,
#    'instant_price': None,
#    'starting_at': 0.85},
#   'csgotrader': {'price': 1.18}},
#  'M4A1-S | Moss Quartz (Factory New)': {'steam': {'last_90d': 1.41,
#    'last_30d': 1.6,
#    'last_7d': 2.08,
#    'last_24h': 2.15},
#   'bitskins': {'price': '1.55', 'instant_sale_price': None},
#   'lootfarm': 1.85,
#   'csgotm': '1.913',
#   'csmoney': {'price': 2.19},
#   'skincay': {'suggested_price': 1.13,
#    'steam_price': 1.45,
#    'instant_price': None,
#    'starting_at': 4.79},
#   'csgotrader': {'price': 2.15}},
#  'StatTrak™ SG 553 | Aerial (Factory New)': {'steam': {'last_90d': 2.77,
#    'last_30d': 2.68,
#    'last_7d': 2.44,
#    'last_24h': 2.51},
#   'bitskins': {'price': '6.14', 'instant_sale_price': '2.24'},
#   'lootfarm': 2.49,
#   'csgotm': '2.663',
#   'csmoney': {'price': 2.36},
#   'skincay': {'suggested_price': 1.93,
#    'steam_price': 2.47,
#    'instant_price': None,
#    'starting_at': 1.93},
#   'csgotrader': {'price': 2.51}},
#  'G3SG1 | Demeter (Well-Worn)': {'steam': {'last_90d': 1.39,
#    'last_30d': 1.68,
#    'last_7d': 1.95,
#    'last_24h': 2.01},
#   'bitskins': {'price': '0.6', 'instant_sale_price': None},
#   'lootfarm': 1.75,
#   'csgotm': 'null',
#   'csmoney': {'price': 2.23},
#   'skincay': {'suggested_price': 1.13,
#    'steam_price': 1.45,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.75}},
#  'MAG-7 | Chainmail (Factory New)': {'steam': {'last_90d': 1.33,
#    'last_30d': 1.55,
#    'last_7d': 2.04,
#    'last_24h': 2.07},
#   'bitskins': {'price': '1.51', 'instant_sale_price': None},
#   'lootfarm': 1.84,
#   'csgotm': '1.712',
#   'csmoney': {'price': 1.85},
#   'skincay': {'suggested_price': 1.09,
#    'steam_price': 1.4,
#    'instant_price': None,
#    'starting_at': 1.8},
#   'csgotrader': {'price': 2.07}},
#  'StatTrak™ XM1014 | Scumbria (Well-Worn)': {'steam': {'last_90d': 0.26,
#    'last_30d': 0.26,
#    'last_7d': 0.26,
#    'last_24h': 0.26},
#   'bitskins': {'price': '0.28', 'instant_sale_price': None},
#   'lootfarm': 0.23,
#   'csgotm': '0.340',
#   'csmoney': {'price': 0.27},
#   'skincay': {'suggested_price': 0.19,
#    'steam_price': 0.24,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.26}},
#  'Tec-9 | Ice Cap (Minimal Wear)': {'steam': {'last_90d': 0.21,
#    'last_30d': 0.22,
#    'last_7d': 0.21,
#    'last_24h': 0.21},
#   'bitskins': {'price': '0.18', 'instant_sale_price': None},
#   'lootfarm': 0.2,
#   'csgotm': '0.278',
#   'csmoney': {'price': 0.2},
#   'skincay': {'suggested_price': 0.16,
#    'steam_price': 0.2,
#    'instant_price': None,
#    'starting_at': 0.17},
#   'csgotrader': {'price': 0.21}},
#  'StatTrak™ MAC-10 | Stalker (Battle-Scarred)': {'steam': {'last_90d': 18.59,
#    'last_30d': 18.55,
#    'last_7d': 20.27,
#    'last_24h': 25.86},
#   'bitskins': {'price': '17.75', 'instant_sale_price': '7.1'},
#   'lootfarm': 18.71,
#   'csgotm': '21.544',
#   'csmoney': {'price': 23.33},
#   'skincay': {'suggested_price': 13.21,
#    'steam_price': 16.94,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 20.44}},
#  'MP9 | Green Plaid (Factory New)': {'steam': {'last_90d': 1.05,
#    'last_30d': 1.12,
#    'last_7d': 1.12,
#    'last_24h': 1.13},
#   'bitskins': {'price': '0.49', 'instant_sale_price': None},
#   'lootfarm': 1.01,
#   'csgotm': '1.870',
#   'csmoney': {'price': 1.25},
#   'skincay': {'suggested_price': 0.8,
#    'steam_price': 1.03,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.13}},
#  '★ M9 Bayonet | Damascus Steel (Field-Tested)': {'steam': {'last_90d': 220.06,
#    'last_30d': 232.9,
#    'last_7d': 236.07,
#    'last_24h': 236.09},
#   'bitskins': {'price': '212.79', 'instant_sale_price': '85.12'},
#   'lootfarm': 259.38,
#   'csgotm': '255.826',
#   'csmoney': {'price': 240.95},
#   'skincay': {'suggested_price': 166.67,
#    'steam_price': 213.68,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 238.0}},
#  'StatTrak™ Dual Berettas | Cobra Strike (Minimal Wear)': {'steam': {'last_90d': 29.55,
#    'last_30d': 30.43,
#    'last_7d': 33.88,
#    'last_24h': 35.16},
#   'bitskins': {'price': '16.11', 'instant_sale_price': '6.44'},
#   'lootfarm': 30.42,
#   'csgotm': 'null',
#   'csmoney': {'price': 33.24},
#   'skincay': {'suggested_price': 21.41,
#    'steam_price': 27.45,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 31.63}},
#  'Sticker | Spiidi | MLG Columbus 2016': {'steam': {'last_90d': 0.62,
#    'last_30d': 0.59,
#    'last_7d': 0.7,
#    'last_24h': 0},
#   'bitskins': {'price': '0.55', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 0.65},
#   'skincay': {'suggested_price': 0.42,
#    'steam_price': 0.54,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.61}},
#  'AK-47 | Point Disarray (Battle-Scarred)': {'steam': {'last_90d': 15.88,
#    'last_30d': 16.28,
#    'last_7d': 16.5,
#    'last_24h': 16.23},
#   'bitskins': {'price': '16.39', 'instant_sale_price': '6.56'},
#   'lootfarm': 17.14,
#   'csgotm': '16.496',
#   'csmoney': {'price': 17.32},
#   'skincay': {'suggested_price': 11.65,
#    'steam_price': 14.93,
#    'instant_price': None,
#    'starting_at': 11.68},
#   'csgotrader': {'price': 16.23}},
#  'UMP-45 | Delusion (Factory New)': {'steam': {'last_90d': 1.32,
#    'last_30d': 1.38,
#    'last_7d': 1.38,
#    'last_24h': 1.37},
#   'bitskins': {'price': '1.1', 'instant_sale_price': None},
#   'lootfarm': 1.31,
#   'csgotm': '2.862',
#   'csmoney': {'price': 1.48},
#   'skincay': {'suggested_price': 0.99,
#    'steam_price': 1.27,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.39}},
#  'StatTrak™ AWP | Elite Build (Field-Tested)': {'steam': {'last_90d': 15.56,
#    'last_30d': 15.53,
#    'last_7d': 15.91,
#    'last_24h': 15.97},
#   'bitskins': {'price': '18.21', 'instant_sale_price': '7.28'},
#   'lootfarm': 15.26,
#   'csgotm': '15.810',
#   'csmoney': {'price': 17.36},
#   'skincay': {'suggested_price': 11.1,
#    'steam_price': 14.23,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 15.97}},
#  'Sticker | Xyp9x | MLG Columbus 2016': {'steam': {'last_90d': 1.38,
#    'last_30d': 1.44,
#    'last_7d': 1.47,
#    'last_24h': 1.54},
#   'bitskins': {'price': '0.29', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 1.71},
#   'skincay': {'suggested_price': 1.02,
#    'steam_price': 1.31,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.48}},
#  'Sawed-Off | Highwayman (Factory New)': {'steam': {'last_90d': 1.58,
#    'last_30d': 1.57,
#    'last_7d': 1.49,
#    'last_24h': 1.39},
#   'bitskins': {'price': '0.83', 'instant_sale_price': None},
#   'lootfarm': 1.41,
#   'csgotm': '2.169',
#   'csmoney': {'price': 1.69},
#   'skincay': {'suggested_price': 1.13,
#    'steam_price': 1.45,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.5}},
#  'Desert Eagle | Sunset Storm 弐 (Factory New)': {'steam': {'last_90d': 64.03,
#    'last_30d': 65.13,
#    'last_7d': 68.45,
#    'last_24h': 70.86},
#   'bitskins': {'price': '50.25', 'instant_sale_price': '20.1'},
#   'lootfarm': 73.09,
#   'csgotm': '70.471',
#   'csmoney': {'price': 74.98},
#   'skincay': {'suggested_price': 46.45,
#    'steam_price': 59.55,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 70.86}},
#  'AWP | Containment Breach (Field-Tested)': {'steam': {'last_90d': 44.08,
#    'last_30d': 43.32,
#    'last_7d': 44.48,
#    'last_24h': 46.06},
#   'bitskins': {'price': '43.57', 'instant_sale_price': '17.43'},
#   'lootfarm': 47.54,
#   'csgotm': '43.146',
#   'csmoney': {'price': 48.9},
#   'skincay': {'suggested_price': 30.93,
#    'steam_price': 39.65,
#    'instant_price': None,
#    'starting_at': 30.66},
#   'csgotrader': {'price': 46.06}},
#  'PP-Bizon | Blue Streak (Well-Worn)': {'steam': {'last_90d': 0.69,
#    'last_30d': 0.7,
#    'last_7d': 0.71,
#    'last_24h': 0.59},
#   'bitskins': {'price': '0.77', 'instant_sale_price': None},
#   'lootfarm': 0.67,
#   'csgotm': '1.177',
#   'csmoney': {'price': 0.79},
#   'skincay': {'suggested_price': 0.5,
#    'steam_price': 0.64,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.72}},
#  'SCAR-20 | Outbreak (Minimal Wear)': {'steam': {'last_90d': 0.43,
#    'last_30d': 0.4,
#    'last_7d': 0.39,
#    'last_24h': 0.41},
#   'bitskins': {'price': '0.5', 'instant_sale_price': None},
#   'lootfarm': 0.36,
#   'csgotm': '0.456',
#   'csmoney': {'price': 0.44},
#   'skincay': {'suggested_price': 0.29,
#    'steam_price': 0.37,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.41}},
#  'Souvenir MP9 | Setting Sun (Battle-Scarred)': {'steam': {'last_90d': 1.99,
#    'last_30d': 2.03,
#    'last_7d': 2.02,
#    'last_24h': 1.88},
#   'bitskins': {'price': '1.54', 'instant_sale_price': None},
#   'lootfarm': 2.02,
#   'csgotm': 'null',
#   'csmoney': {'price': 2.3},
#   'skincay': {'suggested_price': 1.47,
#    'steam_price': 1.88,
#    'instant_price': None,
#    'starting_at': 1.79},
#   'csgotrader': {'price': 2.04}},
#  'Galil AR | Firefight (Well-Worn)': {'steam': {'last_90d': 0.43,
#    'last_30d': 0.41,
#    'last_7d': 0.41,
#    'last_24h': 0.41},
#   'bitskins': {'price': '0.43', 'instant_sale_price': None},
#   'lootfarm': 0.38,
#   'csgotm': '0.504',
#   'csmoney': {'price': 0.37},
#   'skincay': {'suggested_price': 0.3,
#    'steam_price': 0.39,
#    'instant_price': None,
#    'starting_at': 0.3},
#   'csgotrader': {'price': 0.41}},
#  'Sticker | KRIMZ | Cologne 2016': {'steam': {'last_90d': 0.79,
#    'last_30d': 0.83,
#    'last_7d': 0.93,
#    'last_24h': 0.91},
#   'bitskins': {'price': '0.34', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 0.99},
#   'skincay': {'suggested_price': 0.6,
#    'steam_price': 0.77,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.86}},
#  'MP5-SD | Acid Wash (Factory New)': {'steam': {'last_90d': 0.46,
#    'last_30d': 0.48,
#    'last_7d': 0.5,
#    'last_24h': 0.5},
#   'bitskins': {'price': '0.46', 'instant_sale_price': None},
#   'lootfarm': 0.44,
#   'csgotm': '0.744',
#   'csmoney': {'price': 0.47},
#   'skincay': {'suggested_price': 0.34,
#    'steam_price': 0.44,
#    'instant_price': None,
#    'starting_at': 0.42},
#   'csgotrader': {'price': 0.5}},
#  'G3SG1 | Flux (Minimal Wear)': {'steam': {'last_90d': 6.58,
#    'last_30d': 6.95,
#    'last_7d': 7.21,
#    'last_24h': 7.42},
#   'bitskins': {'price': '6.44', 'instant_sale_price': '2.58'},
#   'lootfarm': 7.34,
#   'csgotm': '7.019',
#   'csmoney': {'price': 7.52},
#   'skincay': {'suggested_price': 4.96,
#    'steam_price': 6.36,
#    'instant_price': None,
#    'starting_at': 4.76},
#   'csgotrader': {'price': 7.42}},
#  'Sticker | karrigan (Foil) | Cologne 2015': {'steam': {'last_90d': 2.47,
#    'last_30d': 2.33,
#    'last_7d': 2.16,
#    'last_24h': 0},
#   'bitskins': {'price': '0.65', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 2.41},
#   'skincay': {'suggested_price': 1.59,
#    'steam_price': 2.04,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 2.18}},
#  'StatTrak™ SG 553 | Atlas (Minimal Wear)': {'steam': {'last_90d': 0.79,
#    'last_30d': 0.75,
#    'last_7d': 0.66,
#    'last_24h': 0.65},
#   'bitskins': {'price': '1.22', 'instant_sale_price': None},
#   'lootfarm': 0.72,
#   'csgotm': '0.953',
#   'csmoney': {'price': 0.67},
#   'skincay': {'suggested_price': 0.54,
#    'steam_price': 0.69,
#    'instant_price': None,
#    'starting_at': 0.62},
#   'csgotrader': {'price': 0.65}},
#  'StatTrak™ R8 Revolver | Reboot (Field-Tested)': {'steam': {'last_90d': 1.75,
#    'last_30d': 1.72,
#    'last_7d': 1.7,
#    'last_24h': 1.67},
#   'bitskins': {'price': '2.5', 'instant_sale_price': '1.0'},
#   'lootfarm': 1.6,
#   'csgotm': '2.235',
#   'csmoney': {'price': 1.66},
#   'skincay': {'suggested_price': 1.23,
#    'steam_price': 1.58,
#    'instant_price': None,
#    'starting_at': 1.32},
#   'csgotrader': {'price': 1.67}},
#  'XM1014 | Quicksilver (Battle-Scarred)': {'steam': {'last_90d': 0.14,
#    'last_30d': 0.13,
#    'last_7d': 0.12,
#    'last_24h': 0.13},
#   'bitskins': {'price': '0.11', 'instant_sale_price': None},
#   'lootfarm': 0.12,
#   'csgotm': '0.301',
#   'csmoney': {'price': 0.13},
#   'skincay': {'suggested_price': 0.1,
#    'steam_price': 0.13,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.13}},
#  'G3SG1 | Orange Crash (Field-Tested)': {'steam': {'last_90d': 0.08,
#    'last_30d': 0.08,
#    'last_7d': 0.08,
#    'last_24h': 0.08},
#   'bitskins': {'price': '0.11', 'instant_sale_price': None},
#   'lootfarm': 0.08,
#   'csgotm': '0.140',
#   'csmoney': {'price': 0.07},
#   'skincay': {'suggested_price': 0.05,
#    'steam_price': 0.07,
#    'instant_price': None,
#    'starting_at': 0.08},
#   'csgotrader': {'price': 0.08}},
#  'StatTrak™ SG 553 | Cyrex (Minimal Wear)': {'steam': {'last_90d': 30.54,
#    'last_30d': 28.09,
#    'last_7d': 27.23,
#    'last_24h': 26.67},
#   'bitskins': {'price': '53.96', 'instant_sale_price': '21.58'},
#   'lootfarm': 28.3,
#   'csgotm': '27.747',
#   'csmoney': {'price': 28.49},
#   'skincay': {'suggested_price': 20.16,
#    'steam_price': 25.85,
#    'instant_price': None,
#    'starting_at': 22.78},
#   'csgotrader': {'price': 26.67}},
#  'StatTrak™ AUG | Bengal Tiger (Minimal Wear)': {'steam': {'last_90d': 23.09,
#    'last_30d': 23.86,
#    'last_7d': 24.13,
#    'last_24h': 0},
#   'bitskins': {'price': '12.78', 'instant_sale_price': '5.11'},
#   'lootfarm': 23.29,
#   'csgotm': 'null',
#   'csmoney': {'price': 26.97},
#   'skincay': {'suggested_price': 17.02,
#    'steam_price': 21.82,
#    'instant_price': None,
#    'starting_at': 17.3},
#   'csgotrader': {'price': 24.33}},
#  'P2000 | Coach Class (Field-Tested)': {'steam': {'last_90d': 1.88,
#    'last_30d': 2.08,
#    'last_7d': 2.11,
#    'last_24h': 0},
#   'bitskins': {'price': '1.5', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': '3.068',
#   'csmoney': {'price': 2.44},
#   'skincay': {'suggested_price': 1.49,
#    'steam_price': 1.91,
#    'instant_price': None,
#    'starting_at': 1.79},
#   'csgotrader': {'price': 2.13}},
#  'M4A1-S | Mecha Industries (Battle-Scarred)': {'steam': {'last_90d': 9.3,
#    'last_30d': 10.31,
#    'last_7d': 10.13,
#    'last_24h': 9.8},
#   'bitskins': {'price': '8.54', 'instant_sale_price': '3.42'},
#   'lootfarm': 10.82,
#   'csgotm': '10.211',
#   'csmoney': {'price': 10.35},
#   'skincay': {'suggested_price': 7.39,
#    'steam_price': 9.48,
#    'instant_price': None,
#    'starting_at': 7.47},
#   'csgotrader': {'price': 9.8}},
#  'StatTrak™ MAC-10 | Curse (Factory New)': {'steam': {'last_90d': 14.77,
#    'last_30d': 15.56,
#    'last_7d': 16.04,
#    'last_24h': 15.01},
#   'bitskins': {'price': '21.85', 'instant_sale_price': '8.74'},
#   'lootfarm': 15.02,
#   'csgotm': 'null',
#   'csmoney': {'price': 17.94},
#   'skincay': {'suggested_price': 11.14,
#    'steam_price': 14.28,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 16.17}},
#  'MAC-10 | Carnivore (Minimal Wear)': {'steam': {'last_90d': 0.16,
#    'last_30d': 0.15,
#    'last_7d': 0.15,
#    'last_24h': 0.16},
#   'bitskins': {'price': '0.17', 'instant_sale_price': None},
#   'lootfarm': 0.15,
#   'csgotm': '0.263',
#   'csmoney': {'price': 0.14},
#   'skincay': {'suggested_price': 0.11,
#    'steam_price': 0.14,
#    'instant_price': None,
#    'starting_at': 0.13},
#   'csgotrader': {'price': 0.16}},
#  'P2000 | Obsidian (Well-Worn)': {'steam': {'last_90d': 0.4,
#    'last_30d': 0.39,
#    'last_7d': 0.41,
#    'last_24h': 0.42},
#   'bitskins': {'price': '0.39', 'instant_sale_price': None},
#   'lootfarm': 0.36,
#   'csgotm': '0.473',
#   'csmoney': {'price': 0.34},
#   'skincay': {'suggested_price': 0.28,
#    'steam_price': 0.36,
#    'instant_price': None,
#    'starting_at': 0.29},
#   'csgotrader': {'price': 0.42}},
#  'MAC-10 | Classic Crate (Battle-Scarred)': {'steam': {'last_90d': 0.08,
#    'last_30d': 0.08,
#    'last_7d': 0.08,
#    'last_24h': 0.07},
#   'bitskins': {'price': '0.07', 'instant_sale_price': None},
#   'lootfarm': 0.08,
#   'csgotm': '0.119',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 0.05,
#    'steam_price': 0.07,
#    'instant_price': None,
#    'starting_at': 0.05},
#   'csgotrader': {'price': 0.08}},
#  'CZ75-Auto | Indigo (Field-Tested)': {'steam': {'last_90d': 0.09,
#    'last_30d': 0.09,
#    'last_7d': 0.1,
#    'last_24h': 0.11},
#   'bitskins': {'price': '0.08', 'instant_sale_price': None},
#   'lootfarm': 0.1,
#   'csgotm': '0.091',
#   'csmoney': {'price': 0.1},
#   'skincay': {'suggested_price': 0.06,
#    'steam_price': 0.08,
#    'instant_price': None,
#    'starting_at': 0.07},
#   'csgotrader': {'price': 0.11}},
#  'StatTrak™ MP9 | Bioleak (Minimal Wear)': {'steam': {'last_90d': 1.35,
#    'last_30d': 1.31,
#    'last_7d': 1.31,
#    'last_24h': 1.34},
#   'bitskins': {'price': '0.64', 'instant_sale_price': None},
#   'lootfarm': 1.23,
#   'csgotm': '1.439',
#   'csmoney': {'price': 1.33},
#   'skincay': {'suggested_price': 0.94,
#    'steam_price': 1.2,
#    'instant_price': None,
#    'starting_at': 0.96},
#   'csgotrader': {'price': 1.34}},
#  'Tec-9 | Ice Cap (Field-Tested)': {'steam': {'last_90d': 0.11,
#    'last_30d': 0.12,
#    'last_7d': 0.12,
#    'last_24h': 0.12},
#   'bitskins': {'price': '0.11', 'instant_sale_price': None},
#   'lootfarm': 0.11,
#   'csgotm': '0.216',
#   'csmoney': {'price': 0.1},
#   'skincay': {'suggested_price': 0.09,
#    'steam_price': 0.11,
#    'instant_price': None,
#    'starting_at': 0.09},
#   'csgotrader': {'price': 0.12}},
#  'R8 Revolver | Memento (Field-Tested)': {'steam': {'last_90d': 0.13,
#    'last_30d': 0.16,
#    'last_7d': 0.18,
#    'last_24h': 0.19},
#   'bitskins': {'price': '0.16', 'instant_sale_price': None},
#   'lootfarm': 0.16,
#   'csgotm': '0.390',
#   'csmoney': {'price': 0.14},
#   'skincay': {'suggested_price': 0.12,
#    'steam_price': 0.15,
#    'instant_price': None,
#    'starting_at': 0.12},
#   'csgotrader': {'price': 0.19}},
#  'Five-SeveN | Jungle (Well-Worn)': {'steam': {'last_90d': 0.43,
#    'last_30d': 0.44,
#    'last_7d': 0.45,
#    'last_24h': 0.41},
#   'bitskins': {'price': '0.41', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': '1.280',
#   'csmoney': {'price': 0.48},
#   'skincay': {'suggested_price': 0.31,
#    'steam_price': 0.4,
#    'instant_price': None,
#    'starting_at': 0.32},
#   'csgotrader': {'price': 0.45}},
#  'StatTrak™ CZ75-Auto | Polymer (Minimal Wear)': {'steam': {'last_90d': 0.5,
#    'last_30d': 0.51,
#    'last_7d': 0.53,
#    'last_24h': 0.56},
#   'bitskins': {'price': '0.55', 'instant_sale_price': None},
#   'lootfarm': 0.51,
#   'csgotm': '0.662',
#   'csmoney': {'price': 0.49},
#   'skincay': {'suggested_price': 0.37,
#    'steam_price': 0.47,
#    'instant_price': None,
#    'starting_at': 0.37},
#   'csgotrader': {'price': 0.56}},
#  'StatTrak™ M249 | Nebula Crusader (Field-Tested)': {'steam': {'last_90d': 2.24,
#    'last_30d': 2.29,
#    'last_7d': 2.26,
#    'last_24h': 2.18},
#   'bitskins': {'price': '2.31', 'instant_sale_price': None},
#   'lootfarm': 2.32,
#   'csgotm': '2.441',
#   'csmoney': {'price': 2.47},
#   'skincay': {'suggested_price': 1.64,
#    'steam_price': 2.1,
#    'instant_price': None,
#    'starting_at': 1.62},
#   'csgotrader': {'price': 2.18}},
#  'AK-47 | Orbit Mk01 (Field-Tested)': {'steam': {'last_90d': 10.8,
#    'last_30d': 10.98,
#    'last_7d': 11.07,
#    'last_24h': 11.01},
#   'bitskins': {'price': '11.2', 'instant_sale_price': '4.48'},
#   'lootfarm': 11.56,
#   'csgotm': '10.211',
#   'csmoney': {'price': 10.86},
#   'skincay': {'suggested_price': 7.85,
#    'steam_price': 10.06,
#    'instant_price': None,
#    'starting_at': 8.02},
#   'csgotrader': {'price': 11.01}},
#  'StatTrak™ Five-SeveN | Monkey Business (Battle-Scarred)': {'steam': {'last_90d': 4.57,
#    'last_30d': 4.73,
#    'last_7d': 4.91,
#    'last_24h': 4.95},
#   'bitskins': {'price': '5.0', 'instant_sale_price': '2.0'},
#   'lootfarm': 4.64,
#   'csgotm': '5.710',
#   'csmoney': {'price': 5.55},
#   'skincay': {'suggested_price': 3.37,
#    'steam_price': 4.32,
#    'instant_price': None,
#    'starting_at': 3.56},
#   'csgotrader': {'price': 4.95}},
#  'Sawed-Off | Highwayman (Battle-Scarred)': {'steam': {'last_90d': 0.39,
#    'last_30d': 0.36,
#    'last_7d': 0.37,
#    'last_24h': 0.36},
#   'bitskins': {'price': '0.39', 'instant_sale_price': None},
#   'lootfarm': 0.31,
#   'csgotm': '0.560',
#   'csmoney': {'price': 0.41},
#   'skincay': {'suggested_price': 0.26,
#    'steam_price': 0.33,
#    'instant_price': None,
#    'starting_at': 0.3},
#   'csgotrader': {'price': 0.36}},
#  'StatTrak™ XM1014 | Red Python (Well-Worn)': {'steam': {'last_90d': 0.78,
#    'last_30d': 0.77,
#    'last_7d': 0.85,
#    'last_24h': 0.95},
#   'bitskins': {'price': '0.79', 'instant_sale_price': None},
#   'lootfarm': 0.74,
#   'csgotm': '2.158',
#   'csmoney': {'price': 0.91},
#   'skincay': {'suggested_price': 0.55,
#    'steam_price': 0.71,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.8}},
#  'Sticker | Crown (Foil)': {'steam': {'last_90d': 328.29,
#    'last_30d': 334.92,
#    'last_7d': 345.33,
#    'last_24h': 354.13},
#   'bitskins': {'price': '334.33', 'instant_sale_price': '133.73'},
#   'lootfarm': 379.1,
#   'csgotm': '510.550',
#   'csmoney': {'price': 366.7},
#   'skincay': {'suggested_price': 239.02,
#    'steam_price': 306.44,
#    'instant_price': None,
#    'starting_at': 255.78},
#   'csgotrader': {'price': 354.13}},
#  'StatTrak™ Music Kit | Mord Fustang, Diamonds': {'steam': {'last_90d': 4.82,
#    'last_30d': 4.9,
#    'last_7d': 5.1,
#    'last_24h': 5.2},
#   'bitskins': {'price': '5.42', 'instant_sale_price': '1.63'},
#   'lootfarm': 5.12,
#   'csgotm': '4.325',
#   'csmoney': {'price': 5.24},
#   'skincay': {'suggested_price': 3.5,
#    'steam_price': 4.49,
#    'instant_price': None,
#    'starting_at': 3.49},
#   'csgotrader': {'price': 5.2}},
#  'M4A4 | Dark Blossom (Field-Tested)': {'steam': {'last_90d': 0.6,
#    'last_30d': 0.68,
#    'last_7d': 0.87,
#    'last_24h': 0.9},
#   'bitskins': {'price': '0.72', 'instant_sale_price': None},
#   'lootfarm': 0.79,
#   'csgotm': '0.852',
#   'csmoney': {'price': 0.77},
#   'skincay': {'suggested_price': 0.48,
#    'steam_price': 0.61,
#    'instant_price': None,
#    'starting_at': 1.3},
#   'csgotrader': {'price': 0.9}},
#  'XM1014 | Black Tie (Minimal Wear)': {'steam': {'last_90d': 0.86,
#    'last_30d': 0.83,
#    'last_7d': 0.81,
#    'last_24h': 0.8},
#   'bitskins': {'price': '1.0', 'instant_sale_price': None},
#   'lootfarm': 0.81,
#   'csgotm': '1.079',
#   'csmoney': {'price': 0.76},
#   'skincay': {'suggested_price': 0.59,
#    'steam_price': 0.76,
#    'instant_price': None,
#    'starting_at': 2},
#   'csgotrader': {'price': 0.8}},
#  'AK-47 | Point Disarray (Factory New)': {'steam': {'last_90d': 40.7,
#    'last_30d': 42.25,
#    'last_7d': 43.16,
#    'last_24h': 43.71},
#   'bitskins': {'price': '43.63', 'instant_sale_price': '17.45'},
#   'lootfarm': 44.08,
#   'csgotm': '37.393',
#   'csmoney': {'price': 46.26},
#   'skincay': {'suggested_price': 30.14,
#    'steam_price': 38.64,
#    'instant_price': None,
#    'starting_at': 32.1},
#   'csgotrader': {'price': 43.71}},
#  'StatTrak™ Sawed-Off | Fubar (Battle-Scarred)': {'steam': {'last_90d': 0.19,
#    'last_30d': 0.2,
#    'last_7d': 0.19,
#    'last_24h': 0.19},
#   'bitskins': {'price': '0.24', 'instant_sale_price': None},
#   'lootfarm': 0.18,
#   'csgotm': '0.257',
#   'csmoney': {'price': 0.17},
#   'skincay': {'suggested_price': 0.14,
#    'steam_price': 0.18,
#    'instant_price': None,
#    'starting_at': 0.14},
#   'csgotrader': {'price': 0.19}},
#  'Sticker | Luck Skill (Foil)': {'steam': {'last_90d': 4.97,
#    'last_30d': 4.63,
#    'last_7d': 4.95,
#    'last_24h': 5.49},
#   'bitskins': {'price': '3.6', 'instant_sale_price': '1.08'},
#   'lootfarm': 4.75,
#   'csgotm': 'null',
#   'csmoney': {'price': 5.37},
#   'skincay': {'suggested_price': 3.31,
#    'steam_price': 4.24,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 4.99}},
#  'StatTrak™ UMP-45 | Briefing (Minimal Wear)': {'steam': {'last_90d': 0.48,
#    'last_30d': 0.46,
#    'last_7d': 0.45,
#    'last_24h': 0.44},
#   'bitskins': {'price': '0.6', 'instant_sale_price': None},
#   'lootfarm': 0.4,
#   'csgotm': '0.625',
#   'csmoney': {'price': 0.41},
#   'skincay': {'suggested_price': 0.33,
#    'steam_price': 0.42,
#    'instant_price': None,
#    'starting_at': 0.35},
#   'csgotrader': {'price': 0.44}},
#  'Sawed-Off | Yorick (Minimal Wear)': {'steam': {'last_90d': 0.43,
#    'last_30d': 0.4,
#    'last_7d': 0.38,
#    'last_24h': 0.38},
#   'bitskins': {'price': '0.52', 'instant_sale_price': None},
#   'lootfarm': 0.34,
#   'csgotm': '0.494',
#   'csmoney': {'price': 0.4},
#   'skincay': {'suggested_price': 0.29,
#    'steam_price': 0.37,
#    'instant_price': None,
#    'starting_at': 0.3},
#   'csgotrader': {'price': 0.38}},
#  '★ Hydra Gloves | Rattler (Field-Tested)': {'steam': {'last_90d': 127.04,
#    'last_30d': 128.58,
#    'last_7d': 133.2,
#    'last_24h': 129.95},
#   'bitskins': {'price': '161.26', 'instant_sale_price': '64.5'},
#   'lootfarm': 145.46,
#   'csgotm': '119.512',
#   'csmoney': {'price': 126.13},
#   'skincay': {'suggested_price': 91.71,
#    'steam_price': 117.58,
#    'instant_price': None,
#    'starting_at': 99.59},
#   'csgotrader': {'price': 129.95}},
#  'StatTrak™ MP9 | Modest Threat (Well-Worn)': {'steam': {'last_90d': 0.54,
#    'last_30d': 0.55,
#    'last_7d': 0.55,
#    'last_24h': 0.55},
#   'bitskins': {'price': '0.54', 'instant_sale_price': None},
#   'lootfarm': 0.52,
#   'csgotm': '0.991',
#   'csmoney': {'price': 0.51},
#   'skincay': {'suggested_price': 0.39,
#    'steam_price': 0.5,
#    'instant_price': None,
#    'starting_at': 0.42},
#   'csgotrader': {'price': 0.55}},
#  'Dual Berettas | Balance (Minimal Wear)': {'steam': {'last_90d': 0.26,
#    'last_30d': 0.27,
#    'last_7d': 0.3,
#    'last_24h': 0.31},
#   'bitskins': {'price': '0.26', 'instant_sale_price': None},
#   'lootfarm': 0.26,
#   'csgotm': '0.386',
#   'csmoney': {'price': 0.25},
#   'skincay': {'suggested_price': 0.2,
#    'steam_price': 0.25,
#    'instant_price': None,
#    'starting_at': 0.19},
#   'csgotrader': {'price': 0.31}},
#  'M4A1-S | Decimator (Minimal Wear)': {'steam': {'last_90d': 7.25,
#    'last_30d': 7.68,
#    'last_7d': 7.55,
#    'last_24h': 7.54},
#   'bitskins': {'price': '6.64', 'instant_sale_price': '2.66'},
#   'lootfarm': 7.81,
#   'csgotm': '7.084',
#   'csmoney': {'price': 7.36},
#   'skincay': {'suggested_price': 5.51,
#    'steam_price': 7.06,
#    'instant_price': None,
#    'starting_at': 5.93},
#   'csgotrader': {'price': 7.54}},
#  'Sticker | Stupid Banana (Foil)': {'steam': {'last_90d': 4.91,
#    'last_30d': 5.05,
#    'last_7d': 5.13,
#    'last_24h': 5.63},
#   'bitskins': {'price': '6.03', 'instant_sale_price': '1.81'},
#   'lootfarm': 5.12,
#   'csgotm': '7.048',
#   'csmoney': {'price': 5.68},
#   'skincay': {'suggested_price': 3.58,
#    'steam_price': 4.59,
#    'instant_price': None,
#    'starting_at': 4.39},
#   'csgotrader': {'price': 5.63}},
#  'MP9 | Slide (Factory New)': {'steam': {'last_90d': 0.12,
#    'last_30d': 0.12,
#    'last_7d': 0.12,
#    'last_24h': 0.12},
#   'bitskins': {'price': '0.14', 'instant_sale_price': None},
#   'lootfarm': 0.11,
#   'csgotm': '0.204',
#   'csmoney': {'price': 0.11},
#   'skincay': {'suggested_price': 0.09,
#    'steam_price': 0.11,
#    'instant_price': None,
#    'starting_at': 0.09},
#   'csgotrader': {'price': 0.12}},
#  'Sticker | Supreme Master First Class': {'steam': {'last_90d': 0.24,
#    'last_30d': 0.27,
#    'last_7d': 0.26,
#    'last_24h': 0.25},
#   'bitskins': {'price': '0.28', 'instant_sale_price': None},
#   'lootfarm': 0.25,
#   'csgotm': '0.259',
#   'csmoney': {'price': 0.23},
#   'skincay': {'suggested_price': 0.2,
#    'steam_price': 0.25,
#    'instant_price': None,
#    'starting_at': 0.2},
#   'csgotrader': {'price': 0.25}},
#  'StatTrak™ M249 | Spectre (Field-Tested)': {'steam': {'last_90d': 0.32,
#    'last_30d': 0.3,
#    'last_7d': 0.3,
#    'last_24h': 0.29},
#   'bitskins': {'price': '0.46', 'instant_sale_price': None},
#   'lootfarm': 0.27,
#   'csgotm': '0.430',
#   'csmoney': {'price': 0.28},
#   'skincay': {'suggested_price': 0.22,
#    'steam_price': 0.28,
#    'instant_price': None,
#    'starting_at': 0.21},
#   'csgotrader': {'price': 0.29}},
#  'Music Kit | Sean Murray, A*D*8': {'steam': {'last_90d': 2.6,
#    'last_30d': 2.56,
#    'last_7d': 2.48,
#    'last_24h': 2.51},
#   'bitskins': {'price': '2.99', 'instant_sale_price': '0.9'},
#   'lootfarm': 2.36,
#   'csgotm': '4.243',
#   'csmoney': {'price': 2.66},
#   'skincay': {'suggested_price': 1.85,
#    'steam_price': 2.37,
#    'instant_price': None,
#    'starting_at': 2.13},
#   'csgotrader': {'price': 2.51}},
#  'PP-Bizon | Embargo (Field-Tested)': {'steam': {'last_90d': 0.5,
#    'last_30d': 0.48,
#    'last_7d': 0.49,
#    'last_24h': 0.51},
#   'bitskins': {'price': '0.47', 'instant_sale_price': None},
#   'lootfarm': 0.46,
#   'csgotm': '0.648',
#   'csmoney': {'price': 0.44},
#   'skincay': {'suggested_price': 0.34,
#    'steam_price': 0.44,
#    'instant_price': None,
#    'starting_at': 0.34},
#   'csgotrader': {'price': 0.51}},
#  'SCAR-20 | Torn (Minimal Wear)': {'steam': {'last_90d': 0.25,
#    'last_30d': 0.27,
#    'last_7d': 0.3,
#    'last_24h': 0.31},
#   'bitskins': {'price': '0.27', 'instant_sale_price': None},
#   'lootfarm': 0.27,
#   'csgotm': '0.291',
#   'csmoney': {'price': 0.25},
#   'skincay': {'suggested_price': 0.2,
#    'steam_price': 0.25,
#    'instant_price': None,
#    'starting_at': 0.19},
#   'csgotrader': {'price': 0.31}},
#  'MAC-10 | Carnivore (Field-Tested)': {'steam': {'last_90d': 0.1,
#    'last_30d': 0.11,
#    'last_7d': 0.1,
#    'last_24h': 0.1},
#   'bitskins': {'price': '0.12', 'instant_sale_price': None},
#   'lootfarm': 0.1,
#   'csgotm': '0.143',
#   'csmoney': {'price': 0.09},
#   'skincay': {'suggested_price': 0.08,
#    'steam_price': 0.1,
#    'instant_price': None,
#    'starting_at': 0.08},
#   'csgotrader': {'price': 0.1}},
#  'StatTrak™ Sawed-Off | Highwayman (Minimal Wear)': {'steam': {'last_90d': 2.6,
#    'last_30d': 2.68,
#    'last_7d': 2.88,
#    'last_24h': 3.07},
#   'bitskins': {'price': '1.54', 'instant_sale_price': None},
#   'lootfarm': 2.75,
#   'csgotm': '4.979',
#   'csmoney': {'price': 3.15},
#   'skincay': {'suggested_price': 1.91,
#    'steam_price': 2.45,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 3.07}},
#  'StatTrak™ CZ75-Auto | Pole Position (Well-Worn)': {'steam': {'last_90d': 1.46,
#    'last_30d': 1.45,
#    'last_7d': 1.37,
#    'last_24h': 1.36},
#   'bitskins': {'price': '0.84', 'instant_sale_price': None},
#   'lootfarm': 1.27,
#   'csgotm': '1.798',
#   'csmoney': {'price': 1.5},
#   'skincay': {'suggested_price': 1.03,
#    'steam_price': 1.32,
#    'instant_price': None,
#    'starting_at': 1.45},
#   'csgotrader': {'price': 1.36}},
#  'StatTrak™ AUG | Torque (Well-Worn)': {'steam': {'last_90d': 3.15,
#    'last_30d': 3.22,
#    'last_7d': 3.26,
#    'last_24h': 3.32},
#   'bitskins': {'price': '2.1', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': '4.099',
#   'csmoney': {'price': 3.65},
#   'skincay': {'suggested_price': 2.29,
#    'steam_price': 2.94,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 3.29}},
#  'Sticker | NiKo | Cluj-Napoca 2015': {'steam': {'last_90d': 10.88,
#    'last_30d': 12.78,
#    'last_7d': 0,
#    'last_24h': 0},
#   'bitskins': {'price': '1.06', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 9.07,
#    'steam_price': 11.63,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 13.28}},
#  'StatTrak™ Glock-18 | Ironwork (Field-Tested)': {'steam': {'last_90d': 0.65,
#    'last_30d': 0.66,
#    'last_7d': 0.64,
#    'last_24h': 0.64},
#   'bitskins': {'price': '0.71', 'instant_sale_price': None},
#   'lootfarm': 0.63,
#   'csgotm': '0.699',
#   'csmoney': {'price': 0.57},
#   'skincay': {'suggested_price': 0.48,
#    'steam_price': 0.61,
#    'instant_price': None,
#    'starting_at': 0.47},
#   'csgotrader': {'price': 0.64}},
#  'MP7 | Impire (Field-Tested)': {'steam': {'last_90d': 0.75,
#    'last_30d': 0.79,
#    'last_7d': 0.8,
#    'last_24h': 0.79},
#   'bitskins': {'price': '0.7', 'instant_sale_price': None},
#   'lootfarm': 0.75,
#   'csgotm': '0.919',
#   'csmoney': {'price': 0.88},
#   'skincay': {'suggested_price': 0.57,
#    'steam_price': 0.73,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.79}},
#  'MAG-7 | Praetorian (Field-Tested)': {'steam': {'last_90d': 0.73,
#    'last_30d': 0.76,
#    'last_7d': 0.81,
#    'last_24h': 0.79},
#   'bitskins': {'price': '0.69', 'instant_sale_price': None},
#   'lootfarm': 0.75,
#   'csgotm': '0.921',
#   'csmoney': {'price': 0.83},
#   'skincay': {'suggested_price': 0.55,
#    'steam_price': 0.7,
#    'instant_price': None,
#    'starting_at': 0.58},
#   'csgotrader': {'price': 0.79}},
#  'StatTrak™ Dual Berettas | Cartel (Field-Tested)': {'steam': {'last_90d': 0.33,
#    'last_30d': 0.34,
#    'last_7d': 0.35,
#    'last_24h': 0.36},
#   'bitskins': {'price': '0.38', 'instant_sale_price': None},
#   'lootfarm': 0.32,
#   'csgotm': '0.420',
#   'csmoney': {'price': 0.38},
#   'skincay': {'suggested_price': 0.24,
#    'steam_price': 0.31,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.36}},
#  'MAC-10 | Nuclear Garden (Battle-Scarred)': {'steam': {'last_90d': 1.9,
#    'last_30d': 2.19,
#    'last_7d': 2.18,
#    'last_24h': 2.18},
#   'bitskins': {'price': '0.29', 'instant_sale_price': None},
#   'lootfarm': 2.09,
#   'csgotm': '2.567',
#   'csmoney': {'price': 2.56},
#   'skincay': {'suggested_price': 1.56,
#    'steam_price': 2,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 2.18}},
#  'StatTrak™ Dual Berettas | Balance (Field-Tested)': {'steam': {'last_90d': 0.42,
#    'last_30d': 0.46,
#    'last_7d': 0.48,
#    'last_24h': 0.48},
#   'bitskins': {'price': '0.43', 'instant_sale_price': None},
#   'lootfarm': 0.43,
#   'csgotm': '0.429',
#   'csmoney': {'price': 0.45},
#   'skincay': {'suggested_price': 0.33,
#    'steam_price': 0.42,
#    'instant_price': None,
#    'starting_at': 0.33},
#   'csgotrader': {'price': 0.48}},
#  'FAMAS | Decommissioned (Well-Worn)': {'steam': {'last_90d': 0.09,
#    'last_30d': 0.08,
#    'last_7d': 0.09,
#    'last_24h': 0.09},
#   'bitskins': {'price': '0.09', 'instant_sale_price': None},
#   'lootfarm': 0.09,
#   'csgotm': '0.186',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 0.05,
#    'steam_price': 0.07,
#    'instant_price': None,
#    'starting_at': 0.06},
#   'csgotrader': {'price': 0.09}},
#  'StatTrak™ G3SG1 | Orange Crash (Field-Tested)': {'steam': {'last_90d': 0.27,
#    'last_30d': 0.27,
#    'last_7d': 0.26,
#    'last_24h': 0.26},
#   'bitskins': {'price': '0.3', 'instant_sale_price': None},
#   'lootfarm': 0.24,
#   'csgotm': '0.346',
#   'csmoney': {'price': 0.24},
#   'skincay': {'suggested_price': 0.2,
#    'steam_price': 0.25,
#    'instant_price': None,
#    'starting_at': 0.2},
#   'csgotrader': {'price': 0.26}},
#  'SCAR-20 | Powercore (Field-Tested)': {'steam': {'last_90d': 0.35,
#    'last_30d': 0.34,
#    'last_7d': 0.35,
#    'last_24h': 0.35},
#   'bitskins': {'price': '0.35', 'instant_sale_price': None},
#   'lootfarm': 0.33,
#   'csgotm': '0.484',
#   'csmoney': {'price': 0.31},
#   'skincay': {'suggested_price': 0.24,
#    'steam_price': 0.31,
#    'instant_price': None,
#    'starting_at': 0.24},
#   'csgotrader': {'price': 0.35}},
#  'R8 Revolver | Canal Spray (Minimal Wear)': {'steam': {'last_90d': 0.2,
#    'last_30d': 0.18,
#    'last_7d': 0.21,
#    'last_24h': 0.21},
#   'bitskins': {'price': '0.18', 'instant_sale_price': None},
#   'lootfarm': 0.18,
#   'csgotm': '0.185',
#   'csmoney': {'price': 0.19},
#   'skincay': {'suggested_price': 0.13,
#    'steam_price': 0.17,
#    'instant_price': None,
#    'starting_at': 0.12},
#   'csgotrader': {'price': 0.21}},
#  'StatTrak™ PP-Bizon | Photic Zone (Well-Worn)': {'steam': {'last_90d': 0.39,
#    'last_30d': 0.41,
#    'last_7d': 0.41,
#    'last_24h': 0.43},
#   'bitskins': {'price': '0.4', 'instant_sale_price': None},
#   'lootfarm': 0.37,
#   'csgotm': '0.522',
#   'csmoney': {'price': 0.43},
#   'skincay': {'suggested_price': 0.3,
#    'steam_price': 0.38,
#    'instant_price': None,
#    'starting_at': 0.3},
#   'csgotrader': {'price': 0.43}},
#  'SCAR-20 | Stone Mosaico (Minimal Wear)': {'steam': {'last_90d': 0.2,
#    'last_30d': 0.18,
#    'last_7d': 0.21,
#    'last_24h': 0.21},
#   'bitskins': {'price': '0.18', 'instant_sale_price': None},
#   'lootfarm': 0.18,
#   'csgotm': '0.156',
#   'csmoney': {'price': 0.19},
#   'skincay': {'suggested_price': 0.13,
#    'steam_price': 0.17,
#    'instant_price': None,
#    'starting_at': 0.12},
#   'csgotrader': {'price': 0.21}},
#  'XM1014 | Scumbria (Battle-Scarred)': {'steam': {'last_90d': 0.09,
#    'last_30d': 0.09,
#    'last_7d': 0.09,
#    'last_24h': 0.09},
#   'bitskins': {'price': '0.11', 'instant_sale_price': None},
#   'lootfarm': 0.09,
#   'csgotm': '0.221',
#   'csmoney': {'price': 0.07},
#   'skincay': {'suggested_price': 0.06,
#    'steam_price': 0.08,
#    'instant_price': None,
#    'starting_at': 0.07},
#   'csgotrader': {'price': 0.09}},
#  '★ Karambit | Ultraviolet (Field-Tested)': {'steam': {'last_90d': 276.89,
#    'last_30d': 284.51,
#    'last_7d': 290.58,
#    'last_24h': 0},
#   'bitskins': {'price': '268.94', 'instant_sale_price': '107.58'},
#   'lootfarm': 311.79,
#   'csgotm': '301.714',
#   'csmoney': {'price': 302.18},
#   'skincay': {'suggested_price': 203.42,
#    'steam_price': 260.79,
#    'instant_price': None,
#    'starting_at': 201.86},
#   'csgotrader': {'price': 292.96}},
#  '★ Bayonet | Damascus Steel (Field-Tested)': {'steam': {'last_90d': 189.97,
#    'last_30d': 200.71,
#    'last_7d': 208.99,
#    'last_24h': 206.73},
#   'bitskins': {'price': '195.21', 'instant_sale_price': '78.08'},
#   'lootfarm': 220.73,
#   'csgotm': '189.339',
#   'csmoney': {'price': 211.56},
#   'skincay': {'suggested_price': 143.02,
#    'steam_price': 183.36,
#    'instant_price': None,
#    'starting_at': 147},
#   'csgotrader': {'price': 210.7}},
#  'FAMAS | Styx (Battle-Scarred)': {'steam': {'last_90d': 1.89,
#    'last_30d': 1.86,
#    'last_7d': 1.89,
#    'last_24h': 1.87},
#   'bitskins': {'price': '0.65', 'instant_sale_price': None},
# ...
#   'csmoney': {'price': 9.82},
#   'skincay': {'suggested_price': 6.74,
#    'steam_price': 8.64,
#    'instant_price': None,
#    'starting_at': 7.04},
#   'csgotrader': {'price': 9.3}},
#  'Sticker | balblna (Gold) | London 2018': {'steam': {'last_90d': 10.73,
#    'last_30d': 10.15,
#    'last_7d': 18.31,
#    'last_24h': 18.68},
#   'bitskins': {'price': '3.51', 'instant_sale_price': '1.05'},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 7.58},
#   'skincay': {'suggested_price': 7.26,
#    'steam_price': 9.31,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 10.55}},
#  'Souvenir P250 | Facility Draft (Field-Tested)': {'steam': {'last_90d': 0.28,
#    'last_30d': 0.29,
#    'last_7d': 0.3,
#    'last_24h': 0.29},
#   'bitskins': {'price': '0.25', 'instant_sale_price': None},
#   'lootfarm': 0.27,
#   'csgotm': '2.877',
#   'csmoney': {'price': 0.27},
#   'skincay': {'suggested_price': 0.21,
#    'steam_price': 0.27,
#    'instant_price': None,
#    'starting_at': 0.5},
#   'csgotrader': {'price': 0.29}},
#  'Sticker | emagine | Cologne 2015': {'steam': {'last_90d': 1.12,
#    'last_30d': 0,
#    'last_7d': 0,
#    'last_24h': 0},
#   'bitskins': {'price': '0.61', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 0.92},
#   'skincay': {'suggested_price': 1.42,
#    'steam_price': 1.82,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.91}},
#  'Sticker | TACO (Foil) | Atlanta 2017': {'steam': {'last_90d': 6.02,
#    'last_30d': 6.03,
#    'last_7d': 6.99,
#    'last_24h': 0},
#   'bitskins': {'price': '1.67', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 4.63},
#   'skincay': {'suggested_price': 4.31,
#    'steam_price': 5.53,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 6.27}},
#  'Souvenir USP-S | Night Ops (Battle-Scarred)': {'steam': {'last_90d': 34.31,
#    'last_30d': 0,
#    'last_7d': 0,
#    'last_24h': 0},
#   'bitskins': {'price': '23.69', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 24.61,
#    'steam_price': 31.55,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 26.96}},
#  'Sticker | StarLadder (Holo) | Berlin 2019': {'steam': {'last_90d': 0.49,
#    'last_30d': 0.54,
#    'last_7d': 0.57,
#    'last_24h': 0.57},
#   'bitskins': {'price': '0.54', 'instant_sale_price': None},
#   'lootfarm': 0.55,
#   'csgotm': '0.617',
#   'csmoney': {'price': 0.52},
#   'skincay': {'suggested_price': 0.39,
#    'steam_price': 0.5,
#    'instant_price': None,
#    'starting_at': 0.45},
#   'csgotrader': {'price': 0.57}},
#  'Sticker | SANJI (Foil) | Berlin 2019': {'steam': {'last_90d': 0.13,
#    'last_30d': 0.18,
#    'last_7d': 0.19,
#    'last_24h': 0.19},
#   'bitskins': {'price': '0.11', 'instant_sale_price': None},
#   'lootfarm': 0.17,
#   'csgotm': '0.676',
#   'csmoney': {'price': 0.17},
#   'skincay': {'suggested_price': 0.13,
#    'steam_price': 0.17,
#    'instant_price': None,
#    'starting_at': 0.13},
#   'csgotrader': {'price': 0.19}},
#  'Sticker | Ramz1kBO$$ (Gold) | Berlin 2019': {'steam': {'last_90d': 8.12,
#    'last_30d': 8.87,
#    'last_7d': 9.73,
#    'last_24h': 0},
#   'bitskins': {'price': '9.08', 'instant_sale_price': '2.72'},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 8.76},
#   'skincay': {'suggested_price': 6.35,
#    'steam_price': 8.14,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 9.22}},
#  '★ Hydra Gloves | Emerald (Battle-Scarred)': {'steam': {'last_90d': 133.76,
#    'last_30d': 135.3,
#    'last_7d': 138.93,
#    'last_24h': 152.77},
#   'bitskins': {'price': '176.5', 'instant_sale_price': '70.6'},
#   'lootfarm': 150.23,
#   'csgotm': '136.612',
#   'csmoney': {'price': 140},
#   'skincay': {'suggested_price': 96.77,
#    'steam_price': 124.07,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 140.07}},
#  'MP5-SD | Agent (Well-Worn)': {'steam': {'last_90d': 0.37,
#    'last_30d': 0.36,
#    'last_7d': 0.37,
#    'last_24h': 0.37},
#   'bitskins': {'price': '0.36', 'instant_sale_price': None},
#   'lootfarm': 0.34,
#   'csgotm': '0.498',
#   'csmoney': {'price': 0.3},
#   'skincay': {'suggested_price': 0.26,
#    'steam_price': 0.33,
#    'instant_price': None,
#    'starting_at': 0.24},
#   'csgotrader': {'price': 0.37}},
#  'Desert Eagle | Emerald Jörmungandr (Field-Tested)': {'steam': {'last_90d': 43.16,
#    'last_30d': 44.7,
#    'last_7d': 51.14,
#    'last_24h': 54.26},
#   'bitskins': {'price': '43.19', 'instant_sale_price': '17.28'},
#   'lootfarm': 49.5,
#   'csgotm': '60.995',
#   'csmoney': {'price': 61.96},
#   'skincay': {'suggested_price': 31.54,
#    'steam_price': 40.44,
#    'instant_price': None,
#    'starting_at': 45.25},
#   'csgotrader': {'price': 54.26}},
#  'Sealed Graffiti | Mr. Teeth (Frog Green)': {'steam': {'last_90d': 0.03,
#    'last_30d': 0.03,
#    'last_7d': 0.03,
#    'last_24h': 0.03},
#   'bitskins': {'price': '0.03', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': '0.129',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 0.02,
#    'steam_price': 0.03,
#    'instant_price': None,
#    'starting_at': 0.02},
#   'csgotrader': {'price': 0.03}},
#  'StatTrak™ Glock-18 | Oxide Blaze (Field-Tested)': {'steam': {'last_90d': 0.59,
#    'last_30d': 0.59,
#    'last_7d': 0.57,
#    'last_24h': 0.57},
#   'bitskins': {'price': '0.7', 'instant_sale_price': None},
#   'lootfarm': 0.55,
#   'csgotm': '0.504',
#   'csmoney': {'price': 0.48},
#   'skincay': {'suggested_price': 0.42,
#    'steam_price': 0.54,
#    'instant_price': None,
#    'starting_at': 0.43},
#   'csgotrader': {'price': 0.57}},
#  '★ Navaja Knife | Safari Mesh (Battle-Scarred)': {'steam': {'last_90d': 65.45,
#    'last_30d': 68.4,
#    'last_7d': 69.43,
#    'last_24h': 0},
#   'bitskins': {'price': '62.62', 'instant_sale_price': '25.05'},
#   'lootfarm': 75.67,
#   'csgotm': '80.976',
#   'csmoney': {'price': 72.56},
#   'skincay': {'suggested_price': 48.97,
#    'steam_price': 62.78,
#    'instant_price': None,
#    'starting_at': 53.5},
#   'csgotrader': {'price': 70.0}},
#  '★ Bowie Knife | Boreal Forest (Minimal Wear)': {'steam': {'last_90d': 114.45,
#    'last_30d': 115.4,
#    'last_7d': 120.65,
#    'last_24h': 0},
#   'bitskins': {'price': '117.26', 'instant_sale_price': '46.9'},
#   'lootfarm': 117.25,
#   'csgotm': 'null',
#   'csmoney': {'price': 131.04},
#   'skincay': {'suggested_price': 82.58,
#    'steam_price': 105.87,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 121.64}},
#  'StatTrak™ CZ75-Auto | Xiangliu (Well-Worn)': {'steam': {'last_90d': 8.24,
#    'last_30d': 8.37,
#    'last_7d': 8.56,
#    'last_24h': 8.09},
#   'bitskins': {'price': '8.88', 'instant_sale_price': '3.55'},
#   'lootfarm': 8.01,
#   'csgotm': '10.489',
#   'csmoney': {'price': 9.04},
#   'skincay': {'suggested_price': 6.01,
#    'steam_price': 7.7,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 8.09}},
#  'Sticker | FaZe Clan | Berlin 2019': {'steam': {'last_90d': 0.8,
#    'last_30d': 1.01,
#    'last_7d': 1.08,
#    'last_24h': 1.11},
#   'bitskins': {'price': '0.32', 'instant_sale_price': None},
#   'lootfarm': 1.05,
#   'csgotm': '0.850',
#   'csmoney': {'price': 0.98},
#   'skincay': {'suggested_price': 0.72,
#    'steam_price': 0.92,
#    'instant_price': None,
#    'starting_at': 0.68},
#   'csgotrader': {'price': 1.11}},
#  'Sticker | arT (Gold) | Berlin 2019': {'steam': {'last_90d': 27.26,
#    'last_30d': 30.08,
#    'last_7d': 34.01,
#    'last_24h': 0},
#   'bitskins': {'price': '42.09', 'instant_sale_price': '12.63'},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 30.34},
#   'skincay': {'suggested_price': 21.53,
#    'steam_price': 27.6,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 31.26}},
#  'Sticker | karrigan (Foil) | Berlin 2019': {'steam': {'last_90d': 0.31,
#    'last_30d': 0.4,
#    'last_7d': 0.45,
#    'last_24h': 0.43},
#   'bitskins': {'price': '0.21', 'instant_sale_price': None},
#   'lootfarm': 0.37,
#   'csgotm': '2.468',
#   'csmoney': {'price': 0.43},
#   'skincay': {'suggested_price': 0.3,
#    'steam_price': 0.38,
#    'instant_price': None,
#    'starting_at': 0.41},
#   'csgotrader': {'price': 0.43}},
#  'CS20 Case Key': {'steam': {'last_90d': 5.57,
#    'last_30d': 5.71,
#    'last_7d': 6.58,
#    'last_24h': 7.91},
#   'bitskins': {'price': '5.56', 'instant_sale_price': '2.22'},
#   'lootfarm': 6.5,
#   'csgotm': '6.760',
#   'csmoney': {'price': 6.94},
#   'skincay': {'suggested_price': 4.06,
#    'steam_price': 5.2,
#    'instant_price': None,
#    'starting_at': 4.69},
#   'csgotrader': {'price': 6.63}},
#  'G3SG1 | Ventilator (Minimal Wear)': {'steam': {'last_90d': 0.11,
#    'last_30d': 0.11,
#    'last_7d': 0.1,
#    'last_24h': 0.1},
#   'bitskins': {'price': '0.13', 'instant_sale_price': None},
#   'lootfarm': 0.1,
#   'csgotm': '0.136',
#   'csmoney': {'price': 0.09},
#   'skincay': {'suggested_price': 0.08,
#    'steam_price': 0.1,
#    'instant_price': None,
#    'starting_at': 0.07},
#   'csgotrader': {'price': 0.1}},
#  'M4A1-S | Control Panel (Field-Tested)': {'steam': {'last_90d': 8.96,
#    'last_30d': 10.16,
#    'last_7d': 10.19,
#    'last_24h': 10.25},
#   'bitskins': {'price': '9.21', 'instant_sale_price': '3.68'},
#   'lootfarm': 10.44,
#   'csgotm': '10.911',
#   'csmoney': {'price': 10.41},
#   'skincay': {'suggested_price': 7.28,
#    'steam_price': 9.33,
#    'instant_price': None,
#    'starting_at': 7.99},
#   'csgotrader': {'price': 10.25}},
#  'StatTrak™ Tec-9 | Jambiya (Minimal Wear)': {'steam': {'last_90d': 0.67,
#    'last_30d': 0.72,
#    'last_7d': 0.73,
#    'last_24h': 0.77},
#   'bitskins': {'price': '0.65', 'instant_sale_price': None},
#   'lootfarm': 0.69,
#   'csgotm': '1.065',
#   'csmoney': {'price': 0.81},
#   'skincay': {'suggested_price': 0.51,
#    'steam_price': 0.66,
#    'instant_price': None,
#    'starting_at': 0.52},
#   'csgotrader': {'price': 0.77}},
#  'Tec-9 | Tornado (Factory New)': {'steam': {'last_90d': 4.79,
#    'last_30d': 5.31,
#    'last_7d': 5.43,
#    'last_24h': 5.56},
#   'bitskins': {'price': '4.97', 'instant_sale_price': '1.99'},
#   'lootfarm': 'null',
#   'csgotm': 'null',
#   'csmoney': {'price': 5.15},
#   'skincay': {'suggested_price': 3.56,
#    'steam_price': 4.57,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 5.52}},
#  'Sticker | Team EnVyUs | Cologne 2015': {'steam': {'last_90d': 1.03,
#    'last_30d': 1.02,
#    'last_7d': 1,
#    'last_24h': 1.05},
#   'bitskins': {'price': '1.15', 'instant_sale_price': None},
#   'lootfarm': 0.95,
#   'csgotm': '1.438',
#   'csmoney': {'price': 0.97},
#   'skincay': {'suggested_price': 0.73,
#    'steam_price': 0.94,
#    'instant_price': None,
#    'starting_at': 0.73},
#   'csgotrader': {'price': 1.05}},
#  'Souvenir Glock-18 | Night (Factory New)': {'steam': {'last_90d': 23.02,
#    'last_30d': 25.4,
#    'last_7d': 27.45,
#    'last_24h': 0},
#   'bitskins': {'price': '73.47', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': '33.832',
#   'csmoney': {'price': 26.71},
#   'skincay': {'suggested_price': 18.17,
#    'steam_price': 23.3,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 26.4}},
#  'Sticker | Xyp9x | Cologne 2015': {'steam': {'last_90d': 0.98,
#    'last_30d': 1.04,
#    'last_7d': 1.04,
#    'last_24h': 1.07},
#   'bitskins': {'price': '0.96', 'instant_sale_price': None},
#   'lootfarm': 0.98,
#   'csgotm': 'null',
#   'csmoney': {'price': 1.13},
#   'skincay': {'suggested_price': 0.74,
#    'steam_price': 0.95,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 1.05}},
#  'Sealed Graffiti | 8-Ball (Tracer Yellow)': {'steam': {'last_90d': 0.03,
#    'last_30d': 0.03,
#    'last_7d': 0.03,
#    'last_24h': 0.03},
#   'bitskins': {'price': '0.03', 'instant_sale_price': None},
#   'lootfarm': 'null',
#   'csgotm': '0.072',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 0.02,
#    'steam_price': 0.03,
#    'instant_price': None,
#    'starting_at': 0.02},
#   'csgotrader': {'price': 0.03}},
#  'Sticker | Team Liquid (Foil) | Berlin 2019': {'steam': {'last_90d': 3.6,
#    'last_30d': 3.6,
#    'last_7d': 3.97,
#    'last_24h': 3.88},
#   'bitskins': {'price': '5.42', 'instant_sale_price': '1.63'},
#   'lootfarm': 3.74,
#   'csgotm': '4.024',
#   'csmoney': {'price': 4.05},
#   'skincay': {'suggested_price': 2.56,
#    'steam_price': 3.28,
#    'instant_price': None,
#    'starting_at': 2.65},
#   'csgotrader': {'price': 3.88}},
#  'FAMAS | Night Borre (Factory New)': {'steam': {'last_90d': 0.22,
#    'last_30d': 0.26,
#    'last_7d': 0.33,
#    'last_24h': 0.4},
#   'bitskins': {'price': '0.23', 'instant_sale_price': None},
#   'lootfarm': 0.28,
#   'csgotm': '0.370',
#   'csmoney': {'price': 0.32},
#   'skincay': {'suggested_price': 0.18,
#    'steam_price': 0.23,
#    'instant_price': None,
#    'starting_at': 0.49},
#   'csgotrader': {'price': 0.33}},
#  'MAC-10 | Classic Crate (Well-Worn)': {'steam': {'last_90d': 0.08,
#    'last_30d': 0.08,
#    'last_7d': 0.08,
#    'last_24h': 0.08},
#   'bitskins': {'price': '0.08', 'instant_sale_price': None},
#   'lootfarm': 0.07,
#   'csgotm': '0.101',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 0.05,
#    'steam_price': 0.07,
#    'instant_price': None,
#    'starting_at': 0.05},
#   'csgotrader': {'price': 0.08}},
#  'StatTrak™ M4A4 | The Emperor (Minimal Wear)': {'steam': {'last_90d': 187.89,
#    'last_30d': 186.39,
#    'last_7d': 188.54,
#    'last_24h': 193.14},
#   'bitskins': {'price': '240.89', 'instant_sale_price': '96.36'},
#   'lootfarm': 205.46,
#   'csgotm': '181.195',
#   'csmoney': {'price': 202.1},
#   'skincay': {'suggested_price': 133.42,
#    'steam_price': 171.05,
#    'instant_price': None,
#    'starting_at': 140},
#   'csgotrader': {'price': 193.14}},
#  'Sticker | Stewie2K (Gold) | Berlin 2019': {'steam': {'last_90d': 14.05,
#    'last_30d': 16.04,
#    'last_7d': 17.29,
#    'last_24h': 18.56},
#   'bitskins': {'price': '17.42', 'instant_sale_price': '5.23'},
#   'lootfarm': 16.44,
#   'csgotm': 'null',
#   'csmoney': {'price': 17.98},
#   'skincay': {'suggested_price': 11.45,
#    'steam_price': 14.68,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 17.43}},
#  '★ StatTrak™ Shadow Daggers | Ultraviolet (Well-Worn)': {'steam': {'last_90d': 94.75,
#    'last_30d': 99.51,
#    'last_7d': 111.59,
#    'last_24h': 0},
#   'bitskins': {'price': '90.01', 'instant_sale_price': '36.0'},
#   'lootfarm': 113.54,
#   'csgotm': 'null',
#   'csmoney': {'price': 105.24},
#   'skincay': {'suggested_price': 71.21,
#    'steam_price': 91.29,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 103.42}},
#  'Team Roles Capsule': {'steam': {'last_90d': 1.05,
#    'last_30d': 1.05,
#    'last_7d': 1.11,
#    'last_24h': 1.11},
#   'bitskins': {'price': '1.04', 'instant_sale_price': None},
#   'lootfarm': 1.02,
#   'csgotm': '2.431',
#   'csmoney': {'price': 0},
#   'skincay': {'suggested_price': 0.75,
#    'steam_price': 0.96,
#    'instant_price': None,
#    'starting_at': 0.89},
#   'csgotrader': {'price': 1.11}},
#  'Sticker | GuardiaN | London 2018': {'steam': {'last_90d': 0.23,
#    'last_30d': 0.25,
#    'last_7d': 0.28,
#    'last_24h': 0.28},
#   'bitskins': {'price': '0.18', 'instant_sale_price': None},
#   'lootfarm': 0.25,
#   'csgotm': '0.461',
#   'csmoney': {'price': 0.25},
#   'skincay': {'suggested_price': 0.18,
#    'steam_price': 0.23,
#    'instant_price': None,
#    'starting_at': None},
#   'csgotrader': {'price': 0.28}},
#  'AWP | Acheron (Minimal Wear)': {'steam': {'last_90d': 3.57,
#    'last_30d': 3.33,
#    'last_7d': 3.24,
#    'last_24h': 3.12},
#   'bitskins': {'price': '4.39', 'instant_sale_price': '1.76'},
#   'lootfarm': 3.39,
#   'csgotm': '2.517',
#   'csmoney': {'price': 2.98},
#   'skincay': {'suggested_price': 2.39,
#    'steam_price': 3.06,
#    'instant_price': None,
#    'starting_at': 2.46},
#   'csgotrader': {'price': 3.12}},
#  'Sticker | Water Gun': {'steam': {'last_90d': 1.6,
#    'last_30d': 1.69,
#    'last_7d': 1.83,
#    'last_24h': 1.87},
#   'bitskins': {'price': '1.16', 'instant_sale_price': None},
#   'lootfarm': 1.71,
#   'csgotm': 'null',
#   'csmoney': {'price': 1.94},
#   'skincay': {'suggested_price': 1.2,
#    'steam_price': 1.54,
#    'instant_price': None,
#    'starting_at': 1.24},
#   'csgotrader': {'price': 1.87}},
#  ...}

# %%
# case details (from https://csgostash.com/case/2/eSports-2013-Case)
case_name = "eSports-2013-Case"
case_items = {'Blue': ['FAMAS | Doomkitty', 'MAG-7 | Memento', 'M4A4 | Faded Zebra'],
             'Purple': ['Sawed-Off | Orange DDPAT', 'P250 | Splash', 'Galil AR | Orange DDPAT'],
             'Pink': ['AWP | BOOM', 'AK-47 | Red Laminate'],
             'Red': ['P90 | Death by Kitty'],
             'Yellow': ['Knife']} # can't be bothered putting in all 65 knives, 
                                  # so let's just assume $300 avg value for all knives for our purposes

# %%
# implied by float values (from https://totalcsgo.com/skin-conditions)
skin_condition_probs = {'Factory New': 0.07,
                        'Minimal Wear': 0.15,
                        'Field Tested': 0.38,
                        'Well Worn': 0.45,
                        'Battle Scared': 1}
skin_condition_cdf = [0.07, 0.15, 0.38, 0.45, 1]
skin_condition_pdf = [0.07, 0.08, 0.23, 0.07, 0.55]

# %%
# from https://www.skinwallet.com/csgo/best-csgo-cases/#Opening_cases_or_buying_skins
case_drop_probs = {'Blue': 1, #0.7992327
                   'Purple': 0.2007672, #0.1598465
                   'Pink': 0.0409207, #0.0319693
                   'Red': 0.0089514, #0.0063939
                   'Yellow': 0.0025575}
case_drop_cdf = [1, 0.2007672, 0.0409207, 0.0089514, 0.0025575]
case_drop_pdf = [0.7992327, 0.1598465, 0.0319693, 0.0063939, 0.0025575]

stattrack_prob = 0.10 # with this probability we'll double the value

# %%
# not all items in all conditions are actually available on the marketplace
item = 'P90 | Death by Kitty'
for condition in skin_condition_probs:
    item_condition = item+' ('+condition+')'
    print(item_condition)
    try:
        print(data[item_condition]['steam']['last_90d'])
    except:
        pass
# Out:
# P90 | Death by Kitty (Factory New)
# P90 | Death by Kitty (Minimal Wear)
# 50.55
# P90 | Death by Kitty (Field Tested)
# P90 | Death by Kitty (Well Worn)
# P90 | Death by Kitty (Battle Scared)

# %%
def nan_helper(y):
    """Helper to handle indices and logical indices of NaNs.
    (from stackoverflow user snake_charmer
    https://stackoverflow.com/questions/6518811/interpolate-nan-values-in-a-numpy-array)

    Input:
        - y, 1d numpy array with possible NaNs
    Output:
        - nans, logical indices of NaNs
        - index, a function, with signature indices= index(logical_indices),
          to convert logical indices of NaNs to 'equivalent' indices
    Example:
        >>> # linear interpolation of NaNs
        >>> nans, x= nan_helper(y)
        >>> y[nans]= np.interp(x(nans), x(~nans), y[~nans])
    """

    return np.isnan(y), lambda z: z.nonzero()[0]

# %%
def get_prices(item):
    if item == 'Knife':
        return np.array([300])
    else:
        prices = np.empty(5)
        prices[:] = np.nan
        idx = 0
        for condition in skin_condition_probs:
            item_condition = item+' ('+condition+')'
            try:
                prices[idx] = data[item_condition]['steam']['last_90d']
            except:
                pass
            idx += 1
        if np.count_nonzero(~np.isnan(prices)) == 0: # don't extrapolate if we know nothing
            print("No items of any condition found for {} on the marketplace!".format(item))
        else: # fill extrapolate values
            nans, x = nan_helper(prices)
            prices[nans] = np.interp(x(nans), x(~nans), prices[~nans])
    return prices

# %%
case_items_worth = {}
for colour in case_items:
    for item in case_items[colour]:
        case_items_worth[colour] = get_prices(item)

# %%
case_items_worth
# Out:
# {'Blue': array([9.13, 1.93, 1.93, 1.93, 1.93]),
#  'Purple': array([24.14,  6.77,  6.77,  6.77,  6.77]),
#  'Pink': array([143.61,  24.72,  24.72,  24.72,  24.72]),
#  'Red': array([50.55, 50.55, 50.55, 50.55, 50.55]),
#  'Yellow': array([300])}

# %%
expected_item_value = []
for colour in case_items_worth:
    expected_item_value.append(np.sum(case_items_worth[colour] * skin_condition_pdf))
expected_item_value
# Out:
# [2.434, 7.985899999999999, 33.0423, 50.55, 300.0]

# %%
expected_case_value = np.sum(np.asarray(expected_item_value) * case_drop_pdf)
expected_case_value
# Out:
# 5.368651402539999

# %%
case_price = 20
profit_loss = expected_case_value - case_price
expected_number_of_boxes_untill_knife = 1/0.0025575

# %%
profit_loss*expected_number_of_boxes_untill_knife
# Out:
# -5720.957418361681
